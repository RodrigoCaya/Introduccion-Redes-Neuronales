# %% [markdown]
# <center><img src="http://www.exalumnos.usm.cl/wp-content/uploads/2015/06/Isotipo-Negro.gif" title="Title text" width="30%" /></center>
#
# <hr style="height:2px;border:none"/>
# <h1 align='center'> INF-395 Introducción a las redes neuronales artificiales and deep learning 2022-1 </h1>
#
# <H3 align='center'> Ayudantía I: Redes Neuronales Feed Forward </H3>
#
# ----
#
# <H3 align='center'> <b>Profesores: Ricardo Ñanculef - Ignacio Loayza </b> </H3>
# <H3 align='center'> <b>Ayudantes: Francisco Andrades - Mario Mallea </b> </H3>
#
#
#
# <hr style="height:2px;border:none"/>

# %% [markdown]
# ▶ Video:  https://us02web.zoom.us/rec/share/kI91lFMtqlO3ubU2PH4uSBIzSLQr8l93F4aOSr6KAWwt-OtQpUr8LXIbEU7N0OY4.RJiASWQ0xx6Jtsru?startTime=1649188233000 (Código de acceso: FkS3L=R^)

# %% [markdown]
# # Principios básicos

# %% [markdown]
# ## Herramientas

# %% [markdown]
# <p><img alt="Colaboratory logo" height="45px" src="https://upload.wikimedia.org/wikipedia/commons/thumb/3/38/Jupyter_logo.svg/1200px-Jupyter_logo.svg.png" align="left" hspace="10px" vspace="0px">  </p>
#
# #### Jupyter

# %% [markdown]
#  **Project Jupyter** es un proyecto open-source que busca apoyar la ciencia de datos y computación científica en todos los lenguajes de programación.
#
# **Jupyter Notebook** es una aplicación web open-source que permite crear y compartir documentos que contienen código, ecuaciones, visualizaciones y texto.
#
# Vamos a trabajar sobre archivos .ipynb llamados **notebooks** (ahora mismo estas leyendo un notebook) ejecutando código en **Python 3.X**.
#
# Existen diversas formas para trabajar sobre un notebook en tu computador, entre ellas se encuenta:
# - Instalar JupyterLab vía conda o pip (package installer for Python) (más info: https://jupyterlab.readthedocs.io/en/stable/getting_started/installation.html)
# - Instalar una distribución de Anaconda. Esta incluye Python, Jupyter Notebook y otros paquetes de uso común para la computación científica (sitio oficial: https://www.anaconda.com/)
# -En Google Colaboratory (descrito en la siguiente sección).
#
# Tutorial introductorio a Jupyter Notebook:
# https://realpython.com/jupyter-notebook-introduction/

# %% [markdown]
# <p><img alt="Colaboratory logo" height="45px" src="/img/colab_favicon.ico" align="left" hspace="10px" vspace="0px"></p>
#
# #### ¿Qué es Colaboratory?

# %% [markdown]
# Colaboratory, también llamado "Colab", te permite ejecutar y programar en Python en tu navegador con las siguientes ventajas:
# - No requiere configuración
# - Da acceso gratuito a GPUs
# - Permite compartir contenido fácilmente
# - Cargar datos desde Google Drive
#
# Puedes importar un conjunto de datos, entrenar un clasificador con dicho conjunto de datos y evaluar el modelo con pocas líneas de código.
#
# Los **notebooks de Colab** ejecutan código en los servidores en la nube de Google, lo que te permite aprovechar la potencia del hardware de Google, incluidas las GPU y TPU.
#
# *Desventaja:*
# - Tiempos de cómputo a merced de Google.
# - RAM limitada.
# - Desconexión.

# %% [markdown]
# #### Librerías para Deep Learning

# %% [markdown]
# **TensorFlow** es una plataforma de código abierto para el **aprendizaje automático**. Facilita la creación modelos de aprendizaje automático para computadoras de escritorio, dispositivos móviles, la web y la nube.
#
#
# **Keras** es una API de Deep Learning escrita en Python, que se ejecuta sobre la plataforma de TensorFlow. Permite crear prototipos rápidamente, llevar a cabo investigaciones y producir resultados con una API fácil de usar para definir y entrenar Redes Neuronales Artificiales. (https://keras.io/about/)
#
# **Torch** es un framework de computación científica con amplio soporte para algoritmos de Machine Learning. PyTorch es una librería Python de tensores  optimizada para el Deep Learning mediante GPU y CPU basada en Torch.

# %% [markdown]
# ## Machine Learning

# %% [markdown]
# Recordar que un programa **aprende** en base a sus experiencias (datos de entrenamiento) con respecto a una tarea (en simple, clasificación - regresión) y una métrica (accuracy, F1 score, AUC - MSE, MAE ). Si su desempeño en la tarea medido con la métrica mejora con la más experiencia.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Cuestiones a tener en cuenta:
#
#
# * Conjuntos disjuntos: Datos de entenamiento - Validación ( reserva para validar decisiones, está evaluando el poder de generalización ) - Test (se hace inferencia, se aplica el modelo).
#
# * Pasos para presentar un problema.
#
#   1. Análisis exploratorio (entiendes los datos? ves patrones? que tan dificil es el problema a priori?) Le harás algo a tus datos? (estandarizar? añadirle ruido?) por qué?
#   2. Modelamiento, elergir la arquitectura de la red. Valida tus decisiones y prueba más ideas. Esta es una ciencia experimental.
#   3. Preocupate de como presentas tus resultados y conclusiones.
#
# 👀 Para el entrenamiento final usar todos los datos posibles.
#
# *   Overfitting: Cuando un modelo se sobre ajusta a los datos de entrenamiento, osea, el modelo tiene una gran complejidad, 🔶 y ve mermado su resultados en validación.
#
# Soluciones: Cross validation. Métodos de regularización (L2,L1), como imponer un prior que elimine parámetros y por lo tanto, reduzca la complejidad del modelo.
#
# *   Maldición de la dimensionalidad. Al aumentar la dimensionalidad del espacio de hipotesis de nuestro modelo parametrico se vuelve cada vez más dificil explorar en el. Supongamos que buscamos los parametros en las esquinas de un hyper cubo, que pasa en 2,3, 8 dimensiones?
#
#
# Hay que ser profundos pero no tanto xd
#
# ![image.png](data:image/png;base64,...)
#
#  Entonces como nuestro espacio de características será aquel cubo, si entrenamos nuestro modelo con datos cercanos al promedio (centroide) al añadir nueva data de testeo será cada vez más probable que caigan fuera de la zona de entrenamiento y si queremos compensar con más data de entrenamiento esta crece exponencialmente.
#
# * Otros problemas que uno enfrenta: Clasificación desbalanceada, jerárquica, multi etiqueta.
#
# Soluciones a nivel datos y a nivel modelo.
#
# * Siempre mejorarás con un ensamblado. Bootstrap ( y si probamos el mismo modelo pero desordenando los datos) + el dilemas sesgo - varianza (si se toma un promedio o una mayoría de votos, el sesgo se mantiene y la varianza se reduce)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Añadir ruido a tu input puede hacer más robusto el aprendizajes de los pesos en la red.
#
# Imágenes: Data Augmentation. Tranfer learning de modelos más grandes casi universales

# %% [markdown]
# 💪 Consejo personal: Revisa brevemente la literatura al respecto (¿cómo han abordado el problema?) y deja fluir tu imaginación.

# %% [markdown]
# 3.4 - perro
# 3.4 + 0.1 -perro
# 3.4 -0.1 -perro
#
# 3.5 - perro

# %% [markdown]
# # Redes Neuronales FF

# %% [markdown]
# Una red es un modelo estadístico parámetrico (depende de parámetros entrenables, los pesos "W" y los sesgos "b" ) no lineal (funciones de activación), que queda totalmente definido al resolver un problema de optimización (minimizar la loss) a través de un descenso del gradiente consiente del grafo de computación definido ( ⭐ el backpropagation ⭐).
#
# 🔶 Es un aproximador universal !
#
# 🤯 Aprender hacer ingeniería de características de manera automática. Lo ves?

# %% [markdown]
# <table align='left'>
# <tr>
# <td><img src='https://miro.medium.com/max/1462/1*dan-1AiINySgHgubVb0vJw.gif' width='550'/></td>
# </tr>
# </table>

# %% [markdown]
# fijemos semillas

# %%
from numpy.random import seed
seed(1)
import tensorflow as tf
tf.random.set_seed(2)

# %% [markdown]
# ## Ejemplo: Reconocimiento de Caracteres

# %% [markdown]
# ### Análisis exploratorio de datos (EDA)

# %%
from keras.datasets import mnist
(X_train, y_train), (X_test, y_test) = mnist.load_data()

import matplotlib.pyplot as plt

fig = plt.figure(figsize=(12, 6))
for i in range(18):
  plt.subplot(3,6,i+1)
  #plt.tight_layout()
  plt.imshow(X_train[i], cmap='gray', interpolation='none')
  plt.title("Digit: {}".format(y_train[i]))
  plt.xticks([])
  plt.yticks([])

plt.show()

print("\n dimensiones ...")

print("X_train shape", X_train.shape)
print("X_test shape", X_test.shape)

X_train = X_train.reshape(60000, 784).astype('float32')
X_test = X_test.reshape(10000, 784).astype('float32')


print("X_train shape", X_train.shape)
print("X_test shape", X_test.shape)
# Out:
# ...
# 11501568/11490434 [==============================] - 0s 0us/step
#  dimensiones ...
# X_train shape (60000, 28, 28)
# X_test shape (10000, 28, 28)
# X_train shape (60000, 784)
# X_test shape (10000, 784)

# %% [markdown]
#  Clases

# %%
import numpy as np
import seaborn as sns
clases, frecuencia = np.unique(y_train, return_counts=True)

fig, ax = plt.subplots(figsize=(10,5),nrows=1)
p = sns.barplot(x=clases, y=frecuencia, palette="rocket",ax=ax)
#plt.setp(p.get_xticklabels(), rotation=90)
ax.set_title('Distribución de los Ejemplos por Clase')
plt.show()

print("")

# %% [markdown]
# ### Modelo

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Activation
#from keras.optimizers import SGD, Adam
from keras.layers import Conv2D, MaxPooling2D, Flatten
from keras.layers import Dropout
from keras import optimizers

model = Sequential()
model.add(Dense(20, input_shape=(784,), activation="relu")) #dim entrada ,
model.add(Dense(20,activation="relu"))
model.add(Dense(10,activation="softmax")) #clases a clasificar
#0.1 , 0.001, 0.0001
opt = tf.keras.optimizers.SGD(0.1) #impacto en velocidad de convergencia y calidad del minimo
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=opt)

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 20)                15700
#
#  dense_1 (Dense)             (None, 20)                420
#
#  dense_2 (Dense)             (None, 10)                210
#
# ...
# Total params: 16,330
# Trainable params: 16,330
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Los parámetros de la capa son los pesos:
#
#
# | W  | b  |  Total (suma) |
# |---|---|---|
# | 784*20  | 20  | 15700  |
# |  20*20 | 20  | 420  |
# |  20*10 |  10 | 210  |

# %%
from keras.utils.vis_utils import plot_model

plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# Activaciones:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# La decisión más popular es RELU, por qué ❓

# %% [markdown]
# Loss de clasificación:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Entrenamiento

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=0) #straify...
#estandarizacion
X_train /= 255 
X_val /= 255
X_test /= 255

n_classes = 10
#las redes reciben one hots.....
target_train = to_categorical(y_train, n_classes)
target_val = to_categorical(y_val, n_classes)
target_test = to_categorical(y_test, n_classes)

print("Formas Targets: ", target_train.shape, target_val.shape, target_test.shape)
# Out:
# Formas Targets:  (48000, 10) (12000, 10) (10000, 10)

# %% [markdown]
# *   batch_size: Define la aproximación de gradiente. A un mayor numéro más fiable es la aproximación de montecarlo pero es más pesado el entrenamiento
# *   Epochs: Iteraciones de entrenamiento

# %% [markdown]
# validation data solamente monitorea printeando la métrica

# %%
history = model.fit(X_train, target_train, batch_size=16, epochs=20, verbose=2, validation_data=(X_val, target_val))
# Out:
# Epoch 1/20
# 3000/3000 - 16s - loss: 0.2400 - accuracy: 0.9307 - val_loss: 0.1865 - val_accuracy: 0.9452 - 16s/epoch - 5ms/step
# Epoch 2/20
# 3000/3000 - 12s - loss: 0.1680 - accuracy: 0.9503 - val_loss: 0.2149 - val_accuracy: 0.9386 - 12s/epoch - 4ms/step
# Epoch 3/20
# 3000/3000 - 12s - loss: 0.1522 - accuracy: 0.9540 - val_loss: 0.1841 - val_accuracy: 0.9487 - 12s/epoch - 4ms/step
# Epoch 4/20
# 3000/3000 - 12s - loss: 0.1406 - accuracy: 0.9566 - val_loss: 0.1648 - val_accuracy: 0.9538 - 12s/epoch - 4ms/step
# Epoch 5/20
# 3000/3000 - 12s - loss: 0.1329 - accuracy: 0.9606 - val_loss: 0.1772 - val_accuracy: 0.9509 - 12s/epoch - 4ms/step
# Epoch 6/20
# 3000/3000 - 13s - loss: 0.1251 - accuracy: 0.9612 - val_loss: 0.1503 - val_accuracy: 0.9563 - 13s/epoch - 4ms/step
# Epoch 7/20
# 3000/3000 - 12s - loss: 0.1209 - accuracy: 0.9626 - val_loss: 0.1843 - val_accuracy: 0.9482 - 12s/epoch - 4ms/step
# Epoch 8/20
# ...

# %% [markdown]
#  Evaluación

# %%
import matplotlib.pyplot as plt
fig, axis = plt.subplots(1, 2, figsize=(18,8))
axis[0].plot(history.history['val_accuracy'], label='val_acc')
axis[0].plot(history.history['accuracy'], label='train_acc')
axis[0].set_title("Accuracy")
axis[0].legend()
axis[1].plot(history.history['loss'], label='loss')
axis[1].set_title("Loss en entrenamiento")
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

Y_pred = model.predict(X_test)
print(model.evaluate(X_test, target_test))
print(Y_pred.shape,target_test.shape)

# hay deshacer el one hot
y_pred_crisp = np.argmax(Y_pred, axis=1)
y_test_crisp = np.argmax(target_test, axis=1)

target_names = [str(i) for i in range(10)]

print("\nConfusion Matrix\n")
fig, ax = plt.subplots(figsize=(15, 15))
cm = confusion_matrix(y_test_crisp, y_pred_crisp)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=target_names)
disp = disp.plot(ax=ax,cmap=plt.cm.Blues)
plt.show()

print("\nClassification Report\n")

print(classification_report(y_test_crisp, y_pred_crisp, target_names=target_names))
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1632 - accuracy: 0.9523
# [0.16324950754642487, 0.9523000121116638]
# (10000, 10) (10000, 10)
#
# Confusion Matrix
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       980
#            1       0.99      0.99      0.99      1135
#            2       0.89      0.98      0.93      1032
#            3       0.95      0.93      0.94      1010
#            4       0.96      0.96      0.96       982
#            5       0.95      0.95      0.95       892
#            6       0.95      0.97      0.96       958
#            7       0.96      0.95      0.95      1028
#            8       0.98      0.88      0.93       974
#            9       0.97      0.94      0.95      1009
#
#     accuracy                           0.95     10000
#    macro avg       0.95      0.95      0.95     10000
# weighted avg       0.95      0.95      0.95     10000

# %% [markdown]
# ## Ejemplo: Predicción del Precio de una Casa

# %% [markdown]
# ### Análisis exploratorio de datos (EDA)
#
# http://lib.stat.cmu.edu/datasets/boston

# %%
from keras.datasets import boston_housing


(X_train, y_train), (X_test, y_test) = boston_housing.load_data(
    path="boston_housing.npz", test_split=0.2, seed=113
)

print("\nFormas ...")

print("X_train shape", X_train.shape)
print("X_test shape", X_test.shape)
# Out:
# ...
# 65536/57026 [==================================] - 0s 0us/step
#
# Formas ...
# X_train shape (404, 13)
# X_test shape (102, 13)

# %%
import pandas as pd

# %%
concat= pd.DataFrame(np.concatenate((X_train, y_train.reshape(-1,1)),axis=1))

# %%
fig = plt.figure(figsize=(10, 10))
sns.heatmap(concat.corr(),annot=True, cmap="rocket")
plt.plot()
# Out:
# []

# %%
fig, axes = plt.subplots(figsize=(22,9), nrows=3, ncols=5)
for i, column in enumerate(concat.columns):
      sns.boxplot(x=concat[column],ax=axes[i//5,i%5]) ##grafica

plt.show()

# %% [markdown]
# Estandarizamos

# %% [markdown]
# Se podría considerar la eliminación de observaciones outlayers en ciertas características

# %% [markdown]
# ### Modelo

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
import tensorflow as tf


def create_boston_model(optimizer='rmsprop', nneuron=14):
  
  model = Sequential()
  model.add(Dense(nneuron, input_shape=(X_train.shape[1],), kernel_initializer='normal', activation='relu')) #dim entrada,
  model.add(Dense(nneuron//2, kernel_initializer='normal', activation='relu'))
  model.add(Dense(1, activation="linear", kernel_initializer='normal')) #regresion

  opt = tf.keras.optimizers.RMSprop(learning_rate=0.1)
  model.compile(loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()],  optimizer=opt) 
  return model

# %% [markdown]
# kernel_initializer: inicialización de pesos en las neuronas

# %% [markdown]
# Entrenamiento

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=0)

scaler = StandardScaler()
#Z = X-mu/sigma

x_train = scaler.fit_transform(X_train)
x_val = scaler.transform(X_val)
x_test = scaler.transform(X_test) # se aplica, no se overfitten

# %% [markdown]
# Evaluación

# %%
model = create_boston_model(optimizer='rmsprop', nneuron=48)
history = model.fit(x_train, y_train, batch_size=128, epochs=50, verbose=1, validation_data=(x_val, y_val))
# Out:
# Epoch 1/50
# 3/3 [==============================] - 2s 327ms/step - loss: 1108.6064 - root_mean_squared_error: 33.2957 - mean_absolute_percentage_error: 142.6134 - val_loss: 346.8725 - val_root_mean_squared_error: 18.6245 - val_mean_absolute_percentage_error: 72.8828
# Epoch 2/50
# 3/3 [==============================] - 0s 64ms/step - loss: 223.8674 - root_mean_squared_error: 14.9622 - mean_absolute_percentage_error: 54.5992 - val_loss: 121.8995 - val_root_mean_squared_error: 11.0408 - val_mean_absolute_percentage_error: 42.2900
# Epoch 3/50
# 3/3 [==============================] - 0s 42ms/step - loss: 107.6953 - root_mean_squared_error: 10.3776 - mean_absolute_percentage_error: 36.2241 - val_loss: 26.3314 - val_root_mean_squared_error: 5.1314 - val_mean_absolute_percentage_error: 22.9228
# Epoch 4/50
# ...

# %%
import numpy as np
ypred_test = model.predict(x_test)
print(x_test.shape, ypred_test.shape)
mae = np.mean(np.abs(y_test-ypred_test))
print(mae)
# Out:
# (102, 13) (102, 1)
# 8.96676810571479

# %%
import matplotlib.pyplot as plt
fig, axis = plt.subplots(2, 2, figsize=(18,5))
axis[0,0].plot(history.history['loss'], label='mse')
axis[0,1].plot(history.history['val_loss'], label='val_mse')
axis[1,0].plot(history.history['mean_absolute_percentage_error'], label='mse')#root_mean_squared_error
axis[1,1].plot(history.history['val_mean_absolute_percentage_error'], label='val_mse')
axis[0,0].set_title("Loss versus Número de Epocas Entrenamiento")
axis[0,1].set_title("Loss versus Número de Epocas Validación")
axis[1,0].set_title("Otra Metrica versus Número de Epocas Entrenamiento")
axis[1,1].set_title("Otra Metrica versus Número de Epocas Validación")
plt.tight_layout()
plt.show()

# %% [markdown]
# una loss ruidosa implica pobres aproximaciones del gradiente, Debe subir el bach size!!

# %%
import pandas as pd
fig = plt.figure(figsize=(10, 10))
plt.scatter(y_test,ypred_test)
plt.title("Estudio de la predicción")
plt.plot()
# Out:
# []

# %% [markdown]
#  Selección

# %% [markdown]
# un resultado más robusto con cv
#
# ![image.png](data:image/png;base64,...)

# %%
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold


kfold = KFold(n_splits=10) #3 
results = cross_val_score(KerasRegressor(build_fn=create_boston_model, epochs=20, batch_size=5, verbose=0), x_train, y_train, cv=kfold)
cv_error = -results.mean()
cv_std =  results.std()
print("CV MSE del Modelo: %.2f (%.2f) MSE" % (cv_error,cv_std))#sklearn devuelve negativo
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   import sys
# CV MSE del Modelo: 16.75 (8.70) MSE

# %% [markdown]
# seleccion de hiperparametros

# %% [markdown]
# no pasen de las 5 capas ocultas. 1024-512- 300- 120

# %%
from sklearn.model_selection import GridSearchCV

model = KerasRegressor(build_fn=create_boston_model, epochs=20, batch_size=5, verbose=0)

optimizers = ['rmsprop'] #['rmsprop', 'adam', 'SGD']
init = ['glorot_uniform', 'normal', 'uniform'] #inicializadores
epochs = [ 10] #puede ser pesado ocupar muchas
batches = [10]
nneurons = [6,12,24,48,96]#lista a probar

param_grid = dict(optimizer=optimizers, epochs=epochs, batch_size=batches, nneuron=nneurons)
grid = GridSearchCV(estimator=model, param_grid=param_grid) #esto hace el cv, parametro cv dice cuantas particiones el default es 5
grid_result = grid.fit(x_train, y_train)

print("Best: %f con %s" % (np.absolute(grid_result.best_score_), grid_result.best_params_))

means = np.absolute(grid_result.cv_results_['mean_test_score'])
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']

for mean, stdev, param in zip(means, stds, params):
	print("%f (%f) con: %r" % (mean, stdev, param))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Best: 23.548090 con {'batch_size': 10, 'epochs': 10, 'nneuron': 96, 'optimizer': 'rmsprop'}
# 57.291514 (30.749800) con: {'batch_size': 10, 'epochs': 10, 'nneuron': 6, 'optimizer': 'rmsprop'}
# 28.882514 (26.044746) con: {'batch_size': 10, 'epochs': 10, 'nneuron': 12, 'optimizer': 'rmsprop'}
# 33.232538 (18.841975) con: {'batch_size': 10, 'epochs': 10, 'nneuron': 24, 'optimizer': 'rmsprop'}
# 29.134654 (21.261049) con: {'batch_size': 10, 'epochs': 10, 'nneuron': 48, 'optimizer': 'rmsprop'}
# 23.548090 (9.428123) con: {'batch_size': 10, 'epochs': 10, 'nneuron': 96, 'optimizer': 'rmsprop'}
